# %% [markdown]
# # QLoRA Training with mlx_lm.lora CLI
#
# This notebook now provides instructions to train Mistral-7B with LoRA adapters using the `mlx_lm.lora` command-line interface (CLI) tool, executed via a Python script.

# %% [markdown]
# ## 1. Setup and Imports (Minimal)

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

print('✓ Basic imports OK')
# Out:
# ✓ Basic imports OK

# %% [markdown]
# ## 2. Setup Paths

# %%
PROJECT_ROOT = Path("/Users/f.nuno/Desktop/chatbot_2.0/LLM_training")
DATA_DIR = PROJECT_ROOT / "data"
CHECKPOINT_DIR = PROJECT_ROOT / "checkpoints"
CHECKPOINT_DIR.mkdir(exist_ok=True)

print(f"Project root: {PROJECT_ROOT}")
print(f"Checkpoint dir: {CHECKPOINT_DIR}")
# Out:
# Project root: /Users/f.nuno/Desktop/chatbot_2.0/LLM_training
# Checkpoint dir: /Users/f.nuno/Desktop/chatbot_2.0/LLM_training/checkpoints

# %% [markdown]
# ## 3. Run Training via Script
#
# The training process is now handled by the `scripts/train_with_monitoring.py` script, which invokes the `mlx_lm.lora` CLI tool. This simplifies data loading and training loop management.
#
# To run the training, execute the script from your terminal:
# ```bash
# python3 /Users/f.nuno/Desktop/chatbot_2.0/LLM_training/scripts/train_with_monitoring.py
# ```
#
# The script will print the training configuration and progress to the console. Checkpoints and adapters will be saved in the `checkpoints/adapters` directory.

# %%
# This cell is a placeholder. Execute the script directly from your terminal.
# You can uncomment the line below and run it if you prefer to execute from the notebook, but direct terminal execution is recommended.
# !python3 {PROJECT_ROOT}/scripts/train_with_monitoring.py
print("Training will be initiated via the external script.")
# Out:
# Training will be initiated via the external script.

# %% [markdown]
# ## 4. Post-Training Information
#
# After the training script completes, you can inspect the generated logs and checkpoints in the `checkpoints/adapters` directory. The `mlx_lm.lora` CLI handles its own logging and saving of adapters.

# %%
print("\n✓ All done!")
print(f"\nMetrics and adapters saved in: {CHECKPOINT_DIR}/adapters/")
# Out:
# ✓ All done!
#
# Metrics and adapters saved in: /Users/f.nuno/Desktop/chatbot_2.0/LLM_training/checkpoints/adapters/
